# %% [markdown]
# pyfwc
# =======================
#
# A simple python wrapper for Australian Fair Work Commission API (https://uatdeveloper.fwc.gov.au/)
#
# Requirements
# -----
#
# 1. Register on the [official website](https://uatdeveloper.fwc.gov.au/) and obtain a subscription key
# 2. Install package by the following command:
# `pip install pyfwc`
#
# Usage
# -----

# %% [markdown]
# Create FWC API object

# %%
from pyfwc import FWCAPI
fwc = FWCAPI(YOUR_SUBSCRIPTION_KEY)

# %% [markdown]
# Award
# -----

# %% [markdown]
# Retrieve all awards for the specified parameters

# %%
fwc.get_awards(name='mining')
# Out:
#    award_id  award_fixed_id      code                                   name  \
# 0      1132               1  MA000001  Black Coal Mining Industry Award 2020
# 1      1142              11  MA000011             Mining Industry Award 2020
#
#         award_operative_from award_operative_to  version_number  \
# 0  2010-01-01T00:00:00+00:00               None               3
# 1  2010-01-01T00:00:00+00:00               None               2
#
#      last_modified_datetime   published_year
# 0  2022-01-17T16:12:10+00:00            2021
# 1  2022-01-20T15:49:41+00:00            2021

# %% [markdown]
# Retrieve specific award using an award identifier

# %%
fwc.get_award(id_or_code='MA000001').head(3)
# Out:
#    award_id  award_fixed_id      code                                   name  \
# 0         0               1  MA000001  Black Coal Mining Industry Award 2020
# 1         0               1  MA000001  Black Coal Mining Industry Award 2020
# 2         0               1  MA000001  Black Coal Mining Industry Award 2020
#
#         award_operative_from award_operative_to  version_number  \
# 0  2010-01-01T00:00:00+00:00               None               3
# 1  2010-01-01T00:00:00+00:00               None               3
# 2  2010-01-01T00:00:00+00:00               None               3
#
#      last_modified_datetime   published_year
# 0  2022-01-17T16:12:10+00:00            2021
# 1  2021-06-26T11:33:16+00:00            2020
# 2  2019-10-23T11:12:07+00:00            2019

# %% [markdown]
# Classifications
# -----

# %% [markdown]
# Retrieve a current individual classification using a fixed identifier.

# %%
fwc.get_classification(id_or_code='MA000002',classification_fixed_id='98')
# Out:
#    classification_fixed_id  clause_fixed_id clauses  clause_description  \
# 0                       98                3    16.1  Clerical Employees
#
#   parent_classification_name  classification  classification_level  \
# 0                       None  Level 1—Year 1                     1
#
#   next_down_classification_fixed_id  next_up_classification_fixed_id  \
# 0                              None                               99
#
#               operative_from operative_to  version_number  \
# 0  2021-07-01T00:00:00+00:00         None               1
#
#       last_modified_datetime  published_year
# 0  2022-03-03T18:52:51+00:00            2021

# %% [markdown]
# Retrieve all the pay-rates for an award using an award identifier.

# %%
fwc.get_payrates(id_or_code='MA000001').head(3)
# Out:
#    classification_fixed_id base_pay_rate_id base_rate_type  base_rate  \
# 0                       18             None           None        NaN
# 1                        8                            None        NaN
# 2                    90835             None           None        NaN
#
#   calculated_pay_rate_id calculated_rate_type  calculated_rate  \
# 0                   None                 None              0.0
# 1                   None                 None              0.0
# 2                   None                 None              0.0
#
#   parent_classification_name  \
# 0                    Group B
# 1                    Group A
# 2          Adult apprentices
#
#                                       classification classification_level  \
# 0  (Adult coal mining industry employee engaged i...                  NaN
# 1  (Adult coal mining industry employees, without...                  NaN
# 2  Adult apprentices - % of the Mineworker - Indu...                  NaN
#
#   employee_rate_type_code             operative_from operative_to  \
# 0                    None  2021-07-01T00:00:00+00:00         None
# 1                    None  2021-07-01T00:00:00+00:00         None
# 2                    None  2021-07-01T00:00:00+00:00         None
#
#   version_number  published_year     last_modified_datetime
# 0              1            2021  2022-03-03T18:52:51+00:00
# 1              2            2021  2022-03-03T18:52:51+00:00
# 2              1            2021  2022-01-13T16:41:36+00:00

# %% [markdown]
# Retrieve award classification information using an award identifier.

# %%
fwc.get_classifications(id_or_code='MA000012').head(3)
# Out:
#    classification_fixed_id  clause_fixed_id clauses  clause_description  \
# 0                      549               31    16.1  Pharmacy employees
# 1                      553               31    16.1  Pharmacy employees
# 2                      550               31    16.1  Pharmacy employees
#
#   parent_classification_name                       classification  \
# 0                       None           Pharmacy assistant level 1
# 1                       None  Pharmacy student—1st year of course
# 2                       None           Pharmacy assistant level 2
#
#   classification_level next_down_classification_fixed_id  \
# 0                  1.0                               NaN
# 1                  1.0                             549.0
# 2                  2.0                             553.0
#
#   next_up_classification_fixed_id             operative_from operative_to  \
# 0                           553.0  2021-07-01T00:00:00+00:00         None
# 1                           550.0  2021-07-01T00:00:00+00:00         None
# 2                           554.0  2021-07-01T00:00:00+00:00         None
#
#    version_number     last_modified_datetime  published_year
# 0               1  2022-03-03T18:52:51+00:00            2021
# 1               1  2022-03-03T18:52:51+00:00            2021
# 2               1  2022-03-03T18:52:51+00:00            2021

# %% [markdown]
# Retrieve the current pay-rate for a classification using a fixed identifier.

# %%
fwc.get_current_payrate(id_or_code='MA000012',classification_fixed_id='549')
# Out:
#    classification_fixed_id base_pay_rate_id base_rate_type  base_rate  \
# 0                      549          BR90099         Weekly      848.5
#
#   calculated_pay_rate_id calculated_rate_type  calculated_rate  \
# 0                CR25779               Hourly            22.33
#
#   parent_classification_name              classification  \
# 0                       None  Pharmacy assistant level 1
#
#    classification_level employee_rate_type_code             operative_from  \
# 0                     1                      AD  2021-07-01T00:00:00+00:00
#
#   operative_to  version_number  published_year     last_modified_datetime
# 0         None               1            2021  2022-03-03T18:52:51+00:00

# %% [markdown]
# Expense Allowances
# -----

# %% [markdown]
# Retrieve a current individual expense-related allowance using a fixed identifier.

# %%
fwc.get_expense_allowance(id_or_code='MA000012',expense_allowance_fixed_id='49')
# Out:
#    expense_allowance_fixed_id  clause_fixed_id     clauses  \
# 0                          49             1864  19.3(b)(i)
#
#   allowance_type_code parent_allowance  \
# 0                None             None
#
#                                            allowance  is_all_purpose  \
# 0  Meal allowance—overtime which exceeds 1.5 hour...           False
#
#    allowance_amount payment_frequency  last_adjusted_year  \
# 0             19.69      per occasion                2020
#
#   cpi_quarter_last_adjusted             operative_from operative_to  \
# 0             March Quarter  2021-07-01T00:00:00+00:00         None
#
#    version_number    last_modified_datetime   published_year
# 0               1  2022-02-15T15:41:38+00:00            2021

# %% [markdown]
# Retrieve award expense-related allowance information using an award identifier.

# %%
fwc.get_expense_allowances(id_or_code='MA000012').head(3)
# Out:
#    expense_allowance_fixed_id  clause_fixed_id     clauses  \
# 0                          49             1864  19.3(b)(i)
# 1                        9660            23173     19.3(c)
# 2                          53             1867        19.7
#
#   allowance_type_code parent_allowance  \
# 0                None             None
# 1                None             None
# 2                None             None
#
#                                            allowance  is_all_purpose  \
# 0  Meal allowance—overtime which exceeds 1.5 hour...           False
# 1      Meal allowance—overtime which exceeds 4 hours           False
# 2                            Motor vehicle allowance           False
#
#    allowance_amount payment_frequency  last_adjusted_year  \
# 0             19.69      per occasion                2020
# 1             17.64      per occasion                2020
# 2              0.80            per km                2020
#
#   cpi_quarter_last_adjusted             operative_from operative_to  \
# 0             March Quarter  2021-07-01T00:00:00+00:00         None
# 1             March Quarter  2021-07-01T00:00:00+00:00         None
# 2             March Quarter  2020-07-01T00:00:00+00:00         None
#
#    version_number    last_modified_datetime   published_year
# 0               1  2022-02-15T15:41:38+00:00            2021
# 1               1  2022-02-15T15:41:38+00:00            2021
# 2               1  2022-02-15T15:41:38+00:00            2021

# %% [markdown]
# Penalties
# -----

# %% [markdown]
# Retrieve all the penalties for an award using an award identifier.

# %%
fwc.get_penalties(id_or_code='MA000012').head(3)
# Out:
#    penalty_fixed_id  clause_fixed_id  \
# 0              2132            21735
# 1              2132            21735
# 2              2133            21735
#
#                                   clause_description classification_level  \
# 0  Full-time and part-time adult employees—penalt...                    1
# 1  Full-time and part-time adult employees—penalt...                    1
# 2  Full-time and part-time adult employees—penalt...                    1
#
#   penalty_code                      penalty_description   rate  \
# 0         None   Saturday - Between 6.00 pm and 9.00 pm  150.0
# 1         None   Saturday - Between 6.00 pm and 9.00 pm  150.0
# 2         None  Saturday - Between 9.00 pm and midnight  175.0
#
#   employee_rate_type_code  penalty_calculated_value  \
# 0                      AD                     33.50
# 1                      AD                     33.50
# 2                      AD                     39.08
#
#    calculated_includes_all_purpose base_pay_rate_id  \
# 0                            False          BR90099
# 1                            False          BR90103
# 2                            False          BR90099
#
#               operative_from operative_to version_number  published_year  \
# 0  2021-07-01T00:00:00+00:00         None              1            2021
# 1  2021-07-01T00:00:00+00:00         None              1            2021
# 2  2021-07-01T00:00:00+00:00         None              1            2021
#
#      last_modified_datetime
# 0  2022-01-21T13:24:14+00:00
# 1  2022-01-21T13:24:14+00:00
# 2  2022-01-21T13:24:14+00:00

# %% [markdown]
# Wage Allowances
# -----

# %% [markdown]
# Retrieve a current individual wage-related allowance using a fixed identifier.

# %%
fwc.get_wage_allowance(id_or_code='MA000012',wage_allowance_fixed_id='191')
# Out:
#    wage_allowance_fixed_id  clause_fixed_id clauses allowance_type_code  \
# 0                      191              788    19.9                None
#
#   parent_allowance              allowance  is_all_purpose  rate rate_unit  \
# 0             None  Broken Hill allowance           False  4.28   Percent
#
#   base_pay_rate_id  allowance_amount payment_frequency  \
# 0          BR90101              38.5         per week
#
#               operative_from operative_to  version_number  \
# 0  2021-07-01T00:00:00+00:00         None               1
#
#       last_modified_datetime  published_year
# 0  2022-03-03T09:01:31+00:00            2021

# %% [markdown]
# Retrieve award wage-related allowance information using an award identifier.

# %%
fwc.get_wage_allowances(id_or_code='MA000012').head(3)
# Out:
#    wage_allowance_fixed_id  clause_fixed_id clauses allowance_type_code  \
# 0                      191              788    19.9                None
# 1                    12011            23000    19.2                None
# 2                      191              788    19.9                None
#
#   parent_allowance                                          allowance  \
# 0             None                              Broken Hill allowance
# 1             None  Home medicine reviews or residential medicatio...
# 2             None                              Broken Hill allowance
#
#    is_all_purpose  rate rate_unit base_pay_rate_id  allowance_amount  \
# 0           False  4.28   Percent          BR90101             38.50
# 1           False  0.00   Percent          BR90109            106.40
# 2           False  4.28   Percent             None             37.56
#
#   payment_frequency             operative_from               operative_to  \
# 0         per week   2021-07-01T00:00:00+00:00                       None
# 1          per week  2021-07-01T00:00:00+00:00                       None
# 2         per week   2020-07-01T00:00:00+00:00  2021-06-30T00:00:00+00:00
#
#    version_number     last_modified_datetime  published_year
# 0             1.0  2022-03-03T09:01:31+00:00            2021
# 1             1.0  2022-03-03T09:01:31+00:00            2021
# 2             NaN  2022-03-03T09:01:31+00:00            2020

# %% [markdown]
# Contribution
# -----
# Contributors and committers are are welcome.
